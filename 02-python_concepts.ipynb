# %% [markdown]
# ### Python Programming Concepts

# %% [markdown]
# #### 1. Create a variable to store the value 500 for sales

# %%
sales = 500
sales

# %% [markdown]
# #### 2. Create a variable to store several values:
# * sales: 500, 475, 625
# * integers 1 - 9

# %%
sales = [500, 475, 625]
sales.pop()
# Out:
# 625

# %%
integers = list(range(10,1,-1))
integers
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %% [markdown]
# #### 3. Create a variable to store the names and email addresses for a number of customers
# * John, john@some.com; Ann, ann@some.com

# %%
customers = {"John": "john@some.com", "Ann": "ann@some.com"}
customers
# Out:
# {'John': 'john@some.com', 'Ann': 'ann@some.com'}

# %% [markdown]
# #### 4. Use Python to generate a random value based on each of following:
# 1. between 0 and 1
# 2. the standard normal distribution (rounded to two decimal places)
# 3. a value between 1 and 10
# 4. either H or T

# %%
import random

val1 = random.random()

# %%
round(random.gauss(0, 1), 2)
# Out:
# 0.41

# %%
val3 = random.randint(1, 10)

# %%
val4 = random.choice(['H', 'T'])

# %% [markdown]
# #### 5. Use Python to determine your current working directory

# %%
import os
print(os.getcwd())
# Out:
# /Users/mauriciojosehasbunsiman/OIM3641_F26

# %% [markdown]
# #### 6. Use Python to determine how many days until New Year's Day

# %%
from datetime import date

today = date.today()
new_year = date(today.year + 1, 1, 1)
days_until = (new_year - today).days
print(days_until)
# Out:
# 119

# %% [markdown]
# #### 7. Write a short program that displays the future value of 1,000 earning 5%  at the end of each year for the next 5 years

# %%
principal = 1000
rate = 0.05
years = 5

value = principal
for year in range(1, years + 1):
    value = value * (1 + rate)
    print(f"Year {year}: {value:.2f}")
# Out:
# Year 1: 1050.00
# Year 2: 1102.50
# Year 3: 1157.62
# Year 4: 1215.51
# Year 5: 1276.28

# %% [markdown]
# #### 8. Write a short program that prompts a user to enter a stock symbol and press enter. Add each symbol entered to a variable. The program should run until the user presses the enter key without entering anything (empty string)

# %%
symbols = []

while True:
    symbol = input("Enter a stock symbol (press Enter to stop): ")
    if symbol == "":
        break
    symbols.append(symbol)

print("Symbols entered:", symbols)
# Out:
# Symbols entered: ['AMX']

# %% [markdown]
# #### 9. Write the code necessary to calculate the sum of the square differences of a group of values :
# 58, 32, 37, 41, 36, 36, 54, 37, 25, 53
# ##### $\Sigma $(${x}$ - $\bar{x}$)$^2$

# %%
values = [58, 32, 37, 41, 36, 36, 54, 37, 25, 53]

mean = sum(values) / len(values)
sum_sq_diff = sum((x - mean) ** 2 for x in values)

print("Mean:", mean)
print("Sum of squared differences:", sum_sq_diff)
# Out:
# Mean: 40.9
# Sum of squared differences: 1020.9

# %% [markdown]
# #### 10. Opening, reading and writing files

# %%
with open("example.txt", "w") as file:
    file.write("Hello, this is line 1.\n")
    file.write("This is line 2.\n")

with open("example.txt", "r") as file:
    content = file.read()
    print(content)

with open("example.txt", "r") as file:
    for line in file:
        print(line.strip())

with open("example.txt", "a") as file:
    file.write("This is an appended line.\n")
# Out:
# Hello, this is line 1.
# This is line 2.
#
# Hello, this is line 1.
# This is line 2.

# %% [markdown]
# #### 11. Create a function the will simulate rolling two die and return the value of each and and the sum

# %%
import random

def roll_two_dice():
    die1 = random.randint(1, 6)
    die2 = random.randint(1, 6)
    total = die1 + die2
    return die1, die2, total

die1, die2, total = roll_two_dice()
print(f"Die 1: {die1}, Die 2: {die2}, Sum: {total}")
# Out:
# Die 1: 4, Die 2: 2, Sum: 6

# %% [markdown]
# #### 12. Write the code needed to evaluate whether a value in a group of values is negative or postive and prints an approriate message, i.e. postive, negative
# -1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2

# %%
values = [-1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2]

# %%
for x in values:
    if x > 0:
        print(f"{x}: positive")
    elif x < 0:
        print(f"{x}: negative")
    else:
        print(f"{x}: zero")
# Out:
# -1.59: negative
# 2.36: positive
# 1.69: positive
# 1.13: positive
# -0.91: negative
# 1.48: positive
# -0.34: negative
# 1.31: positive
# -0.74: negative
# 0.2: positive

# %% [markdown]
# #### 14.  Complete the following:
# 1. Write a program that generates 500 random integers from 1 to n, for example, the first integer will be 1 the second will be 1 or 2, the fifth between 1 and 5, and so on.
# 2. The program should write each integer to a file
# 3. Once all integers are written close the file
#
# ##### Part 2
# 1. Open and read the file into a list
# 2. Create a line plot of the data

# %%
import random

filename = "random_integers.txt"

# %%
with open(filename, "w") as file:
    for n in range(1, 501):
        value = random.randint(1, n)
        file.write(f"{value}\n")

# %%
import matplotlib.pyplot as plt

# %%
with open(filename, "r") as fil3:
    data = [int(line.strip()) for line in file]

plt.plot(data)
plt.title("Random Integers (nth value between 1 and n)")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[71], line 3
#       1 filename = "random_integers.txt"
#       2
# ----> 3 with open(filename, "r") as file:
#       4     data = [int(line.strip()) for line in file]
#       5
#       6 plt.plot(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'random_integers.txt'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 plt.plot(data)
#       2 plt.title("Random Integers (nth value between 1 and n)")
#       3 plt.xlabel("Index")
#       4 plt.ylabel("Value")
#
# NameError: name 'plt' is not defined
